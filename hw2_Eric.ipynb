# %%
# !pip install yfinance

# %%
# !pip install pandas

# %%
import yfinance as yf

# %%
df= yf.download("1503.TW", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# !pip install pandas

# %%
df2= yf.download("1504.TW", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df3= yf.download("1513.TW", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df4= yf.download("1514.TW", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df5= yf.download("1519.TW", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df6= yf.download("2382.TW", "2020-01-01")
df7= yf.download("3231.TW", "2020-01-01")
df8= yf.download("6669.TW", "2020-01-01")
df9= yf.download("2421.TW", "2020-01-01")
df10= yf.download("3017.TW", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
df.to_csv("yahoo_1503TW.csv")

# %%
import pandas as pd
df=pd.read_csv("yahoo_1503TW.csv",sep=",",index_col="Date")

# %%
df2.to_csv("yahoo_1504TW.csv")
df3.to_csv("yahoo_1513TW.csv")
df4.to_csv("yahoo_1514TW.csv")
df5.to_csv("yahoo_1519TW.csv")
df6.to_csv("yahoo_2382TW.csv")
df7.to_csv("yahoo_3231TW.csv")
df8.to_csv("yahoo_6669TW.csv")
df9.to_csv("yahoo_2421TW.csv")
df10.to_csv("yahoo_3017TW.csv")

# %%
import pandas as pd


list = ["1459.TW", "1513.TW", "1533.TW","2002.TW","2308.TW","2465.TW","2618.TW","2731.TW","2891.TW","6230.TW"]

for i in list:
    url = "https://raw.githubusercontent.com/leegh2147/stock/main/"+i +".csv"
    df = pd.read_csv(url, index_col=0)
    display(df.head(5))
# Out:
#             Open  High   Low  Close  Adj Close  Volume
# Date
# 2020-01-02  7.53  7.60  7.38   7.44   7.281195  177495
# 2020-01-03  7.44  7.49  7.42   7.43   7.271409  104066
# 2020-01-06  7.39  7.40  7.30   7.30   7.144184   68820
# 2020-01-07  7.29  7.29  7.20   7.25   7.095251   43002
# 2020-01-08  7.20  7.22  7.12   7.15   6.997386   46559
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-01-02  25.000000  25.549999  24.799999  25.549999  22.015316  8776654
# 2020-01-03  25.250000  25.850000  25.049999  25.600000  22.058399  6486604
# 2020-01-06  25.400000  25.500000  25.200001  25.200001  21.713737  2568721
# 2020-01-07  25.250000  25.500000  25.049999  25.450001  21.929152  4051241
# 2020-01-08  25.200001  25.350000  24.700001  25.150000  21.670654  3728817
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2020-01-02  38.049999  38.450001  38.000000  38.000000  37.192101  118703
# ...

# %%
import pandas as pd


list = ["1303TW", "2303TW", "2308TW","2317TW","2353TW","2454TW","3034TW","3037TW","3711TW","4938TW"]

for i in list:
    url = "https://raw.githubusercontent.com/chenyu0501/stock/main/"+ "yahoo_" + i +".csv"
    df = pd.read_csv(url, index_col=0)
    display(df.head(5))
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-01-02  72.800003  72.900002  72.199997  72.599998  59.464767  2189652
# 2020-01-03  72.800003  73.199997  72.599998  73.199997  59.956211  3781701
# 2020-01-06  73.199997  73.199997  72.900002  73.000000  59.792397  2672016
# 2020-01-07  73.000000  73.000000  72.099998  72.599998  59.464767  3377914
# 2020-01-08  72.099998  72.199997  71.599998  71.599998  58.645695  3156434
#                  Open       High    Low      Close  Adj Close    Volume
# Date
# 2020-01-02  16.450001  16.650000  16.40  16.549999  13.364812  32937461
# 2020-01-03  16.549999  16.549999  16.15  16.299999  13.162928  48588354
# 2020-01-06  16.049999  16.150000  15.95  16.049999  12.961041  44790472
# 2020-01-07  16.049999  16.150000  15.80  16.000000  12.920665  39718117
# 2020-01-08  15.850000  15.900000  15.65  15.750000  12.718781  60419690
#              Open   High    Low  Close   Adj Close   Volume
# Date
# ...
